# %% [markdown]
# #### Download Link for Harrcascade files
#
# 1) https://github.com/opencv/opencv/tree/master/data/haarcascades

# %% [markdown]
# #### Notes
# 1) Haarcascade files can detect single or multiple occurences of an object from an image of varying shapes and sizes.
#
# 2) <b>detectMultiScale()</b> - Detects single or multiple occurrence of an object of different sizes in the input image. The detetced features are returned as coordinates.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier("E://Projects//AI_Smartknower//5_Harrcascade//opencv-master//haarcascades//haarcascade_frontalface_alt.xml")
eye_cascade = cv2.CascadeClassifier("E://Projects//AI_Smartknower//5_Harrcascade//opencv-master//haarcascades//haarcascade_eye.xml")

# %% [markdown]
#  #### Face Detection

# %%
def face_detect(img):
    faces = face_cascade.detectMultiScale(img)
    for x,y,w,h in faces:
        
        img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),3)
    print(x,y,w,h)
    plt.imshow(img)
    plt.show()

# %%
w1 = cv2.imread('kneau.jpg')
plt.imshow(w1)
plt.show()

# %%
face_detect(w1)
# Out:
# 89 21 118 118

# %%
w2 = cv2.imread('face2.jpg')
w2 = cv2.cvtColor(w2,cv2.COLOR_BGR2RGB)
plt.imshow(w2)
plt.show()

# %%
face_detect(w2)
# Out:
# 765 65 158 158

# %% [markdown]
# ### Eye-Detection

# %%
def eye_detection(img):
    eyes = eye_cascade.detectMultiScale(img)
    for ex,ey,ew,eh in eyes:
        img = cv2.rectangle(img,(ex,ey),(ex+ew,ey+eh),(0,255,0),3)
    print(ex,ey,ew,eh)
    plt.imshow(img)
    plt.show()

# %%
w1 = cv2.imread('kneau.jpg')
plt.imshow(w1)
plt.show()

# %%
eye_detection(w1)
# Out:
# 156 54 27 27

# %%
w2 = cv2.imread('face2.jpg')
w2 = cv2.cvtColor(w2,cv2.COLOR_BGR2RGB)
plt.imshow(w2)
plt.show()

# %%
eye_detection(w2)
# Out:
# 564 278 24 24

# %% [markdown]
# ### Face_eye_detect

# %%
def face_eye_detect(img):
    faces = face_cascade.detectMultiScale(img)
    for x,y,w,h in faces:        
        img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),3)
        face_color = img[y:y+h,x:x+w]
        eyes = eye_cascade.detectMultiScale(face_color)
        for ex,ey,ew,eh in eyes:
            cv2.rectangle(face_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),3)
            
    plt.imshow(img)
    plt.show()

# %%
w1 = cv2.imread('kneau.jpg')
plt.imshow(w1)
plt.show()

# %%
face_eye_detect(w1)

# %%
w2 = cv2.imread('face2.jpg')
w2 = cv2.cvtColor(w2,cv2.COLOR_BGR2RGB)
plt.imshow(w2)
plt.show()

# %%
face_eye_detect(w2)

# %% [markdown]
# ### Open a webcam

# %%
import cv2

vid = cv2.VideoCapture(0)

while(True):
    ret, frame = vid.read()
    cv2.imshow('frame', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


vid.release()
cv2.destroyAllWindows()



# import cv2

# cap = cv2.VideoCapture(0)

# # Check if the webcam is opened correctly
# if not cap.isOpened():
#     raise IOError("Cannot open webcam")

# while True:
#     ret, frame = cap.read()
#     # frame = cv2.resize(frame, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
#     cv2.imshow('Input', frame)

#     c = cv2.waitKey(1)
#     if c == 27:
#         break

# cap.release()
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Projects\AI_Smartknower\5_Harrcascade\harrcascade_face_eye_detection.ipynb Cell 24 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/e%3A/Projects/AI_Smartknower/5_Harrcascade/harrcascade_face_eye_detection.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> # vid = cv2.VideoCapture(0)
#       <a href='vscode-notebook-cell:/e%3A/Projects/AI_Smartknower/5_Harrcascade/harrcascade_face_eye_detection.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a> while(True):
# ----> <a href='vscode-notebook-cell:/e%3A/Projects/AI_Smartknower/5_Harrcascade/harrcascade_face_eye_detection.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a>     ret, frame = vid.read()
#       <a href='vscode-notebook-cell:/e%3A/Projects/AI_Smartknower/5_Harrcascade/harrcascade_face_eye_detection.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a>     cv2.imshow('frame', frame)
#       <a href='vscode-notebook-cell:/e%3A/Projects/AI_Smartknower/5_Harrcascade/harrcascade_face_eye_detection.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a>     if cv2.waitKey(1) & 0xFF == ord('q'):
#
# NameError: name 'vid' is not defined
